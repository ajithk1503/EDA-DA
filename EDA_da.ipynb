# %% [markdown]
# <a href="https://colab.research.google.com/github/ajithk1503/EDA-DA/blob/main/EDA_da.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("https://raw.githubusercontent.com/salemprakash/EDA/main/Data/telco%20customer%20churn.csv")
data
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents tenure  \
# 0     7590-VHVEG  Female            0.0     Yes         No      1
# 1     5575-GNVDE    Male            0.0      No         No     34
# 2     3668-QPYBK    Male            0.0      No         No      2
# 3     7795-CFOCW    Male            0.0      No         No     45
# 4     9237-HQITU  Female            0.0      No         No      2
# ...          ...     ...            ...     ...        ...    ...
# 7038  6840-RESVB    Male            0.0     Yes        Yes     24
# 7039  2234-XADUH  Female            0.0     Yes        Yes     72
# 7040  4801-JZAZL  Female            0.0     Yes        Yes     11
# 7041  8361-LTMKD    Male            1.0     Yes         No      4
# 7042  3186-AJIEK    Male            0.0      No         No     66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
# dimmensions
print("dimensions of the data set: ",data.shape)
# Out:
# dimensions of the data set:  (7043, 21)

# %%
# summary
print("summary of the data set: ")
print(data.info())
# Out:
# summary of the data set:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7035 non-null   float64
#  3   Partner           7038 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7042 non-null   object
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
# ...

# %% [markdown]
# ## **Data Handling and Cleaning**

# %%
# finding missing values
print(data.isnull().sum())
# Out:
# customerID          0
# gender              0
# SeniorCitizen       8
# Partner             5
# Dependents          0
# tenure              1
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      3
# TotalCharges        0
# Churn               1
# dtype: int64

# %%
# drop duplicates
data = data.drop_duplicates()

# %%
data.tenure = data.tenure.replace(np.nan,0)
data.tenure = pd.to_numeric(data.tenure, errors='coerce')
data.tenure = data.tenure.fillna(data.tenure.mean())

# %%
# filling missing values
data.SeniorCitizen=data.SeniorCitizen.fillna(0)
data.Partner=data.Partner.fillna('No')
data.tenure = data.tenure.replace(np.nan,0)
data.tenure = pd.to_numeric(data.tenure, errors='coerce')
data.tenure = data.tenure.fillna(data.tenure.mean())
data.MonthlyCharges = data.MonthlyCharges.fillna(data.MonthlyCharges.mean())
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               1
# dtype: int64

# %%
# removing a row as the result [Churn] is unknown
data=data.dropna()

# %%
data.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# ## **Univariate, Bivariate and Multivariate Analysis**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Univaraite Analysis

# %%
data.gender.value_counts().plot(kind='pie', figsize=(10,6))
plt.title("Number of observations by Gender")
plt.xlabel('Gender')
plt.show()

# %%
data.SeniorCitizen.value_counts().plot(kind='pie', autopct='%1.1f%%', labels=['No', 'Yes'], colors=['blue','red'], explode=(0.05, 0.05),  startangle=90, figsize=(8,8))
plt.title("Distribution of Senior Citizens")
plt.ylabel('')
plt.show()

# %%
data.Partner.value_counts().plot(kind='bar', figsize=(10,6))
plt.title("Number of observations by Gender")
plt.ylabel('Count')
plt.xlabel('Gender')
plt.show()

# %%
sns.FacetGrid(data).map(sns.histplot, "tenure", kde=True).add_legend()
plt.title('Distribution of Tenure')
plt.show()

# %%
data['StreamingTV'].value_counts().plot(kind='bar', figsize=(10, 6))
plt.title("Number of Observations by StramingTV")
plt.ylabel('Count')
plt.xlabel('Tech Support')
plt.show()

# %%
data.MultipleLines.value_counts().plot(kind='bar', figsize=(10,6))
plt.title("Number of observations by Mutiple Lines of Service")
plt.ylabel('Count')
plt.xlabel('Multiple Lines')
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",data=data)
plt.show()

# %%
data.PaymentMethod.value_counts().plot(kind='bar', figsize=(10,6))
plt.title("Number of observations by Payment Method")
plt.ylabel('Count')
plt.xlabel('Payment Method')
plt.show()

# %%
sns.boxplot(x="TotalCharges",data=data)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %%
plt.scatter(data['gender'], data['Contract'])
plt.title("Scatter Plot for Senior Citizens by Gender")
plt.xlabel("Gender (0: Male, 1: Female)")
plt.ylabel("Contract (Month to Month,One Year,Two Year)")
plt.xticks([0, 1], ['Male', 'Female'])
plt.yticks([0, 1,2], ['Month to Month', 'One Year','Two Year'])
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",y="PhoneService",data=data)
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",y="OnlineBackup",data=data)
plt.show()

# %%
plt.figure(figsize = (9,4))
sns.histplot(x = "tenure",hue= "Churn",data=data)
plt.show()

# %%
sns.boxplot(x="InternetService",y="PhoneService",data=data)
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",y="DeviceProtection",data=data)
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",y="StreamingMovies",data=data)
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",y="Contract",data=data)
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",y="PaymentMethod",data=data)
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(x='Churn', y='MonthlyCharges', data=data)
plt.title('Churn vs MonthlyCharges')
plt.show()

# %%
sns.boxplot(x="MonthlyCharges",y="PaymentMethod",data=data)
plt.show()

# %%
plt.scatter(data['PaymentMethod'], data['MonthlyCharges'])
plt.title("Scatter Plot for Monthly Charges by Payment Method")
plt.xlabel("Payment Method")
plt.ylabel("Monthly Charges")
plt.xticks(range(len(data['PaymentMethod'].unique())), data['PaymentMethod'].unique(), rotation=90)
plt.grid()
plt.show()

# %%
sns.boxplot(x="StreamingMovies",y="PaymentMethod",data=data)
plt.show()

# %% [markdown]
# ## Multivariate Analysis

# %%
correlation = data.corr(method='pearson', numeric_only=True)
sns.heatmap(correlation,xticklabels=correlation.columns,yticklabels=correlation.columns)
# Out:
# <Axes: >

# %%
columns = ['Churn', 'MonthlyCharges', 'tenure', 'TotalCharges', 'InternetService']

sns.pairplot(data[columns], hue='Churn', markers=['o', 's'], height=4)

plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1615: UserWarning:
# The markers list has fewer values (2) than needed (3) and will cycle, which may produce an uninterpretable plot.
#   func(x=x, y=y, **kwargs)

# %%
sns.violinplot(x='InternetService', y='tenure', hue='Churn', data=data, split=True)
plt.show()

# %% [markdown]
# ## Data Summarization and Visualization

# %% [markdown]
# ## 1 D Statistical Analysis

# %%
m=data.TotalCharges.dtype
m
# Out:
# dtype('O')

# %%
# mean
# mean tenure
print("Mean of Tenure: ",data.tenure.mean())
# mean Monthly Charges
print("Mean of Monthly Charges: ",data.MonthlyCharges.mean())
# mean Total Charges
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
print("Mean of Total Charges: ", data.TotalCharges.mean())
# Out:
# Mean of Tenure:  32.37182173321091
# Mean of Monthly Charges:  64.76461739102722
# Mean of Total Charges:  2283.5679277485424

# %%
#median
# mean tenure
print("Mean of Tenure: ",data.tenure.median())
# mean Monthly Charges
print("Mean of Monthly Charges: ",data.MonthlyCharges.median())
# mean Total Charges
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
print("Mean of Total Charges: ", data.TotalCharges.median())
# Out:
# Mean of Tenure:  29.0
# Mean of Monthly Charges:  70.35
# Mean of Total Charges:  1397.65

# %%
# quantiles equal parts of three(3)
# quantile of tenure
quantiles = data.tenure.quantile([0.33, 0.67,1])
print("Quantiles of Tenure:\n",quantiles,'\n')
# quantile of monthly charges
quantiles = data.MonthlyCharges.quantile([0.33, 0.67,1])
print("Quantiles of Monthly Charges:\n",quantiles,'\n')
# quantile of total charges
quantiles = data.TotalCharges.quantile([0.33, 0.67,1])
print("Quantiles of Total Charges:\n",quantiles,'\n')
# Out:
# Quantiles of Tenure:
#  0.33    14.0
# 0.67    47.0
# 1.00    72.0
# Name: tenure, dtype: float64
#
# Quantiles of Monthly Charges:
#  0.33     50.20
# 0.67     84.15
# 1.00    118.75
# Name: MonthlyCharges, dtype: float64
#
# Quantiles of Total Charges:
#  0.33     667.605
# 0.67    2790.735
# 1.00    8684.800
# Name: TotalCharges, dtype: float64

# %%
# deciles
# decile of tenure
deciles = data.tenure.quantile([i/10 for i in range(1, 10)])
print("Deciles of Tenure\n",deciles,"\n")
# decile of monthly charges
deciles = data.MonthlyCharges.quantile([i/10 for i in range(1, 10)])
print("Deciles of Monthly Charges\n",deciles,"\n")
# decile of total charges
deciles = data.TotalCharges.quantile([i/10 for i in range(1, 10)])
print("Deciles of Total Charges\n",deciles,"\n")
# Out:
# Deciles of Tenure
#  0.1     2.0
# 0.2     6.0
# 0.3    12.0
# 0.4    20.0
# 0.5    29.0
# 0.6    40.0
# 0.7    50.0
# 0.8    60.0
# 0.9    69.0
# Name: tenure, dtype: float64
#
# Deciles of Monthly Charges
#  0.1     20.050
# 0.2     25.050
# 0.3     45.865
# 0.4     58.870
# 0.5     70.350
# 0.6     79.100
# 0.7     85.500
# 0.8     94.250
# 0.9    102.600
# Name: MonthlyCharges, dtype: float64
#
# Deciles of Total Charges
#  0.1      84.60
# 0.2     267.00
# 0.3     552.10
# 0.4     944.65
# 0.5    1397.65
# 0.6    2049.05
# 0.7    3141.70
# 0.8    4475.90
# 0.9    5976.90
# Name: TotalCharges, dtype: float64

# %%
# percentile
# percentile of tenure
percentile = data.tenure.quantile([0.25, 0.5, 0.75]) # Calculate quantile for the 'tenure' column only.
print("Percentile of Tenure:\n",percentile,'\n')
# percentile of monthly charges
percentile = data.MonthlyCharges.quantile([0.25, 0.5, 0.75]) # Calculate quantile for the 'MonthlyCharges' column only.
print("Percentile of Monthly Charges:\n",percentile,'\n')
# percentile of total charges
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce') # Ensure 'TotalCharges' is numeric.
percentile = data.TotalCharges.quantile([0.25, 0.5, 0.75]) # Calculate quantile for the 'TotalCharges' column only.
print("Percentile of Total Charges:\n",percentile,'\n')
# Out:
# Percentile of Tenure:
#  0.25     9.0
# 0.50    29.0
# 0.75    55.0
# Name: tenure, dtype: float64
#
# Percentile of Monthly Charges:
#  0.25    35.5125
# 0.50    70.3500
# 0.75    89.8500
# Name: MonthlyCharges, dtype: float64
#
# Percentile of Total Charges:
#  0.25     401.400
# 0.50    1397.650
# 0.75    3794.975
# Name: TotalCharges, dtype: float64

# %% [markdown]
# ## Measures of Dispersion

# %%
from scipy import stats

# %%
# range
# range of tenure
data_range = np.ptp(data.tenure)
print("Range:", data_range)
# range of monthly charges
data_range = np.ptp(data.MonthlyCharges)
print("Range:", data_range)
# range of total charges
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
data_cleaned = data.dropna(subset=['TotalCharges'])
data_range = np.ptp(data_cleaned['TotalCharges'])
print("Range:", data_range)
# Out:
# Range: 72.0
# Range: 100.5
# Range: 8666.0

# %%
# Interquartile Range (IQR)
# IQR for 'tenure'
iqr_tenure = np.percentile(data.tenure, 75) - np.percentile(data.tenure, 25)
print("IQR (tenure):", iqr_tenure)
# IQR for 'MonthlyCharges'
iqr_monthly_charges = np.percentile(data.MonthlyCharges, 75) - np.percentile(data.MonthlyCharges, 25)
print("IQR (MonthlyCharges):", iqr_monthly_charges)
# IQR for 'TotalCharges'
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
data_cleaned = data.dropna(subset=['TotalCharges'])
iqr_total_charges = np.percentile(data_cleaned['TotalCharges'], 75) - np.percentile(data_cleaned['TotalCharges'], 25)
print("IQR (TotalCharges):", iqr_total_charges)
# Out:
# IQR (tenure): 46.0
# IQR (MonthlyCharges): 54.33749999999999
# IQR (TotalCharges): 3393.575

# %%
# Interdecile Range
# Interdecile Range for 'tenure'
interdecile_range_tenure = np.percentile(data.tenure, 90) - np.percentile(data.tenure, 10)
print("Interdecile Range (tenure):", interdecile_range_tenure)

# Interdecile Range for 'MonthlyCharges'
interdecile_range_monthly_charges = np.percentile(data.MonthlyCharges, 90) - np.percentile(data.MonthlyCharges, 10)
print("Interdecile Range (MonthlyCharges):", interdecile_range_monthly_charges)

# Interdecile Range for 'TotalCharges'
interdecile_range_total_charges = np.percentile(data_cleaned['TotalCharges'], 90) - np.percentile(data_cleaned['TotalCharges'], 10)
print("Interdecile Range (TotalCharges):", interdecile_range_total_charges)
# Out:
# Interdecile Range (tenure): 67.0
# Interdecile Range (MonthlyCharges): 82.55
# Interdecile Range (TotalCharges): 5892.299999999999

# %%
# Mean Deviation
# Mean Deviation for 'tenure'
mean_deviation_tenure = np.mean(np.abs(data.tenure - np.mean(data.tenure)))
print("Mean Deviation (tenure):", mean_deviation_tenure)
# Mean Deviation for 'MonthlyCharges'
mean_deviation_monthly_charges = np.mean(np.abs(data.MonthlyCharges - np.mean(data.MonthlyCharges)))
print("Mean Deviation (MonthlyCharges):", mean_deviation_monthly_charges)
# Mean Deviation for 'TotalCharges'
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
data_cleaned = data.dropna(subset=['TotalCharges'])
mean_deviation_total_charges = np.mean(np.abs(data_cleaned['TotalCharges'] - np.mean(data_cleaned['TotalCharges'])))
print("Mean Deviation (TotalCharges):", mean_deviation_total_charges)
# Out:
# Mean Deviation (tenure): 21.874824878614017
# Mean Deviation (MonthlyCharges): 26.210205966992984
# Mean Deviation (TotalCharges): 1899.4889344425699

# %%
# Standard Deviation
# Standard Deviation for 'tenure'
std_dev_tenure = np.std(data.tenure, ddof=1)
print("Standard Deviation (tenure):", std_dev_tenure)
# Standard Deviation for 'MonthlyCharges'
std_dev_monthly_charges = np.std(data.MonthlyCharges, ddof=1)
print("Standard Deviation (MonthlyCharges):", std_dev_monthly_charges)
# Standard Deviation for 'TotalCharges'
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
data_cleaned = data.dropna(subset=['TotalCharges'])
std_dev_total_charges = np.std(data_cleaned['TotalCharges'], ddof=1)
print("Standard Deviation (TotalCharges):", std_dev_total_charges)
# Out:
# Standard Deviation (tenure): 24.561915277129202
# Standard Deviation (MonthlyCharges): 30.08223923079261
# Standard Deviation (TotalCharges): 2266.8215864521653

# %%
# Skewness
# Skewness for 'tenure'
skewness_tenure = stats.skew(data.tenure)
print("Skewness (tenure):", skewness_tenure)
# Skewness for 'MonthlyCharges'
skewness_monthly_charges = stats.skew(data.MonthlyCharges)
print("Skewness (MonthlyCharges):", skewness_monthly_charges)
# Skewness for 'TotalCharges'
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
data_cleaned = data.dropna(subset=['TotalCharges'])
skewness_total_charges = stats.skew(data_cleaned['TotalCharges'])
print("Skewness (TotalCharges):", skewness_total_charges)
# Out:
# Skewness (tenure): 0.23920156183811978
# Skewness (MonthlyCharges): -0.22086989256199907
# Skewness (TotalCharges): 0.9612374318129272

# %%
# Kurtosis
# Kurtosis for 'tenure'
kurtosis_tenure = stats.kurtosis(data.tenure)
print("Kurtosis (tenure):", kurtosis_tenure)
# Kurtosis for 'MonthlyCharges'
kurtosis_monthly_charges = stats.kurtosis(data.MonthlyCharges)
print("Kurtosis (MonthlyCharges):", kurtosis_monthly_charges)
# Kurtosis for 'TotalCharges'
data['TotalCharges'] = pd.to_numeric(data['TotalCharges'], errors='coerce')
data_cleaned = data.dropna(subset=['TotalCharges'])
kurtosis_total_charges = stats.kurtosis(data_cleaned['TotalCharges'])
print("Kurtosis (TotalCharges):", kurtosis_total_charges)
# Out:
# Kurtosis (tenure): -1.3873799207763253
# Kurtosis (MonthlyCharges): -1.2563834134354526
# Kurtosis (TotalCharges): -0.23285990068957352

# %%
# Frequency Distribution
frequency_distribution = data['tenure'].value_counts().sort_index()
print("Frequency Distribution:\n", frequency_distribution)
# Out:
# Frequency Distribution:
#  tenure
# 0.0      12
# 1.0     613
# 2.0     238
# 3.0     200
# 4.0     176
#        ...
# 68.0    100
# 69.0     95
# 70.0    119
# 71.0    170
# 72.0    362
# Name: count, Length: 74, dtype: int64

# %%
# Plotting Frequency Distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=frequency_distribution.index, y=frequency_distribution.values)
plt.title('Frequency Distribution of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Frequency')
plt.show()

# %%
# Histogram
plt.figure(figsize=(10, 5))
plt.hist(data['tenure'], bins=30, edgecolor='black')
plt.title('Histogram of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Frequency')
plt.show()

# %%
# Relative Frequency Distribution
relative_frequency = frequency_distribution / frequency_distribution.sum()
print("Relative Frequency Distribution:\n", relative_frequency)
# Out:
# Relative Frequency Distribution:
#  tenure
# 0.0     0.001704
# 1.0     0.087049
# 2.0     0.033797
# 3.0     0.028401
# 4.0     0.024993
#           ...
# 68.0    0.014201
# 69.0    0.013490
# 70.0    0.016899
# 71.0    0.024141
# 72.0    0.051406
# Name: count, Length: 74, dtype: float64

# %%
# Plotting Relative Frequency Distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=relative_frequency.index, y=relative_frequency.values)
plt.title('Relative Frequency Distribution of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Relative Frequency')
plt.show()

# %%
# Cumulative Frequency Distribution
cumulative_frequency = frequency_distribution.cumsum()
print("Cumulative Frequency Distribution:\n", cumulative_frequency)

# Plotting Cumulative Frequency Distribution
plt.figure(figsize=(10, 5))
plt.plot(cumulative_frequency.index, cumulative_frequency.values, marker='o')
plt.title('Cumulative Frequency Distribution of Tenure')
plt.xlabel('Tenure')
plt.ylabel('Cumulative Frequency')
plt.grid()
plt.show()
# Out:
# Cumulative Frequency Distribution:
#  tenure
# 0.0       12
# 1.0      625
# 2.0      863
# 3.0     1063
# 4.0     1239
#         ...
# 68.0    6296
# 69.0    6391
# 70.0    6510
# 71.0    6680
# 72.0    7042
# Name: count, Length: 74, dtype: int64

# %%
# Pie and Stacked bar plot on categorical varaibles
category_counts = data['SeniorCitizen'].value_counts()

plt.figure(figsize=(8, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Pie Plot of Category Column')
plt.axis('equal')
plt.show()

# %%
# Stacked Bar plot wrt gender and Partner
stacked_data = data.groupby(['gender', 'Partner']).size().unstack(fill_value=0)

stacked_data.plot(kind='bar', stacked=True, figsize=(10, 6))
plt.title('Stacked Bar Plot of Category Column')
plt.xlabel('Category Column')
plt.ylabel('Frequency')
plt.legend(title='Sub Category Column')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# ## 2-D Statistical data Analysis

# %%
# Contingency Table

# Categorical-Categorical
contingency_table = pd.crosstab(data['gender'], data['Partner'])
print("Contingency Table (Categorical-Categorical):")
print(contingency_table)

# row profile
row_profile = contingency_table.div(contingency_table.sum(axis=1), axis=0)
print("\nRow Profile Dataset:")
print(row_profile)

# column profile
column_profile = contingency_table.div(contingency_table.sum(axis=0), axis=1)
print("\nColumn Profile Dataset:")
print(column_profile)

# relative frequency dataset
relative_frequency = contingency_table / contingency_table.sum().sum()
print("\nRelative Frequency Dataset:")
print(relative_frequency)

#chi squared dataset
from scipy.stats import chi2_contingency
chi2_stat, p_value, dof, expected = chi2_contingency(contingency_table)
chi_square_table = pd.DataFrame(expected, index=contingency_table.index, columns=contingency_table.columns)
print("\nChi-Square Dataset (Expected Frequencies):")
print(chi_square_table)
# Out:
# Contingency Table (Categorical-Categorical):
# Partner    No   Yes
# gender
# Female   1801  1687
# Male     1843  1711
#
# Row Profile Dataset:
# Partner        No       Yes
# gender
# Female   0.516342  0.483658
# Male     0.518571  0.481429
#
# Column Profile Dataset:
# Partner        No       Yes
# gender
# Female   0.494237  0.496469
# Male     0.505763  0.503531
#
# Relative Frequency Dataset:
# Partner        No       Yes
# gender
# Female   0.255751  0.239563
# Male     0.261715  0.242971
#
# Chi-Square Dataset (Expected Frequencies):
# Partner           No          Yes
# gender
# Female   1804.923601  1683.076399
# Male     1839.076399  1714.923601

# %%
# Numerical - Categorical
data['Tenure_gender'] = pd.cut(data['tenure'], bins=[0, 20, 40, 60], labels=['Low', 'Medium', 'High'])
contingency_num_cat = pd.crosstab(data['Tenure_gender'], data['gender'])
print("\nContingency Table (Numerical-Categorical):")
print(contingency_num_cat)
# Out:
# Contingency Table (Numerical-Categorical):
# gender         Female  Male
# Tenure_gender
# Low              1430  1435
# Medium            681   727
# High              697   653

# %%
# Numerical - Numerical
correlation_matrix = data[['MonthlyCharges', 'TotalCharges']].corr()
print("\nCorrelation Matrix (Numerical-Numerical):")
print(correlation_matrix)
# Out:
# Correlation Matrix (Numerical-Numerical):
#                 MonthlyCharges  TotalCharges
# MonthlyCharges        1.000000      0.650723
# TotalCharges          0.650723      1.000000

# %%
#  three-way contingency table
contingency_table_3way = pd.crosstab(index=[data['DeviceProtection'], data['StreamingMovies']], columns=data['StreamingTV'])
print("Three-Way Contingency Table:")
print(contingency_table_3way)
# Out:
# Three-Way Contingency Table:
# StreamingTV                                No  No internet service   Yes
# DeviceProtection    StreamingMovies
# No                  No                   1503                    0   454
#                     Yes                   451                    0   686
# No internet service No internet service     0                 1526     0
# Yes                 No                    514                    0   313
#                     Yes                   341                    0  1254

# %% [markdown]
# ##  n-D Statistical data analysis

# %%
# Scatter plot using matplotlib
plt.figure(figsize=(8, 6))
plt.scatter(data['tenure'], data['MonthlyCharges'])
plt.title('Scatter Plot of tenure vs MonthlyCharges')
plt.xlabel('tenure')
plt.ylabel('Monthly Charges')
plt.grid(True)
plt.show()

# %%
# scatter plot for 3 variables
fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data['tenure'], data['MonthlyCharges'], data['SeniorCitizen'], c='b', marker='o')
ax.set_title('3D Scatter Plot of tenure ,MonthlyCharges,SeniorCitizen')
ax.set_xlabel('tenure')
ax.set_ylabel('Monthly Charges')
ax.set_zlabel('Senior Citizen')
plt.show()

# %%
# 2D Boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x='InternetService', y='tenure', data=data)
plt.title('Boxplot of tenure by Internet Service')
plt.xlabel('Internet Service')
plt.ylabel('tenure')
plt.grid(True)
plt.show()

# %%
# Dot plot
plt.figure(figsize=(10, 6))
sns.stripplot(x='StreamingTV', y='TotalCharges', data=data, jitter=True, color='blue', size=8)
plt.title('Dot Plot of TotalCharges by StreamingTV')
plt.xlabel('StreamingTV')
plt.ylabel('TotalCharges')
plt.grid(True)
plt.show()

# %%
# Bar plot
plt.figure(figsize=(10, 6))
sns.barplot(x='StreamingMovies', y='TotalCharges', data=data, estimator='mean', ci=None, palette='viridis')
plt.title('Average TotalCharges by StreamingMovies')
plt.xlabel('StreamingMovies')
plt.ylabel('Average TotalCharges')
plt.grid(True)
plt.show()
# Out:
# <ipython-input-269-da09d262ef4e>:3: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='StreamingMovies', y='TotalCharges', data=data, estimator='mean', ci=None, palette='viridis')
# <ipython-input-269-da09d262ef4e>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='StreamingMovies', y='TotalCharges', data=data, estimator='mean', ci=None, palette='viridis')

# %% [markdown]
# ## K MEANS CLUSTERING

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df=data[['tenure','MonthlyCharges']]
X = scaler.fit_transform(df)
wcss = []

for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, n_init=10, random_state=0)
    kmeans.fit(X)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss, marker='o', color='blue')
plt.xlabel('Number of Clusters (k)')
plt.ylabel('WCSS')
plt.title('Elbow Method for Optimal k')
plt.show()

# %%
# Based on elbow plot, set optimal number of clusters (e.g., 2)
optimal_k = 2
kmeans_model = KMeans(n_clusters=optimal_k, n_init=10, random_state=123)
data['Cluster'] = kmeans_model.fit_predict(X)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=data, x='TotalCharges', y='tenure', hue='Cluster', palette='viridis', s=60)
plt.title('Clusters of Customers')
plt.xlabel('Total Charges')
plt.ylabel('Tenure')
plt.legend(title='Cluster')
plt.show()

print("Number of clusters:", len(data['Cluster'].unique()))
# Out:
# Number of clusters: 2

# %% [markdown]
# ## Hierarchial Clustering for first 50 customers

# %%
import pandas as pd
import numpy as np
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, LabelEncoder
df = data[['tenure', 'customerID']].head(50)

if df['customerID'].dtype == 'object':
    le = LabelEncoder()
    df['customerID_encoded'] = le.fit_transform(df['customerID'])
    X = df[['tenure', 'customerID_encoded']].values
else:
    X = df[['tenure', 'customerID']].values
Z = linkage(X, 'ward')
plt.figure(figsize=(12, 8))
dendrogram(Z, labels=df['customerID'].values, leaf_rotation=90, leaf_font_size=10)
plt.title('Hierarchical Clustering Dendrogram (First 50 Customers)')
plt.xlabel('Customer ID')
plt.ylabel('Distance')
plt.show()

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns

df = data[['tenure','MonthlyCharges','TotalCharges']]
df.dropna(inplace=True)
scaler = StandardScaler()
df_scaled = scaler.fit_transform(df)
pca = PCA()
pca_result = pca.fit_transform(df_scaled)
print("Eigenvalues (Explained Variance Ratio):\n", pca.explained_variance_ratio_)
print("\nComponent Loadings:\n", pd.DataFrame(pca.components_, columns=numeric_columns))
# Out:
# Eigenvalues (Explained Variance Ratio):
#  [0.72654139 0.25356404 0.01989457]
#
# Component Loadings:
#       tenure  MonthlyCharges  TotalCharges
# 0  0.567298        0.485647      0.665071
# 1 -0.606736        0.792544     -0.061191
# 2 -0.556816       -0.368809      0.744269
# <ipython-input-304-05164ae74753>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.dropna(inplace=True)

# %%
plt.figure(figsize=(8, 6))
plt.plot(range(1, len(pca.explained_variance_ratio_)+1), pca.explained_variance_ratio_, marker='o', linestyle='--')
plt.title('Scree Plot')
plt.xlabel('Number of Principal Components')
plt.ylabel('Explained Variance Ratio')
plt.grid(True)
plt.show()

# %%
n_comp = 2

pca_n_comp = PCA(n_components=n_comp)
pca_selected = pca_n_comp.fit_transform(df_scaled)


plt.figure(figsize=(8, 6))
plt.scatter(pca_selected[:, 0], pca_selected[:, 1], edgecolor='k', s=50)
plt.title(f'PCA: First {n_comp} Principal Components')
plt.xlabel('PC1')
plt.ylabel('PC2')
plt.grid(True)
plt.show()

# %%
print("\nExplained Variance by Selected Components:\n", pca_n_comp.explained_variance_ratio_)
print("\nSummary of PCA:\n", pd.DataFrame(pca_n_comp.components_, columns=numeric_columns))
# Out:
# Explained Variance by Selected Components:
#  [0.72654139 0.25356404]
#
# Summary of PCA:
#       tenure  MonthlyCharges  TotalCharges
# 0  0.567298        0.485647      0.665071
# 1 -0.606736        0.792544     -0.061191
